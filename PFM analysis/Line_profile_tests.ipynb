# %%
# Import packages

from vlabs.spm import *
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Location of data files and particular file you want to look at

# %%
data = AsylumDART(os.path.join("data", "P0125OP0001.h5"))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyUSID/io/dtype_utils.py:62: FutureWarning: pyUSID.io.dtype_utils.contains_integers has been moved to sidpy.base.num_utils.contains_integers. This copy in pyUSID willbe removed in future release. Please update your import statements
#   warn('pyUSID.io.dtype_utils.contains_integers has been moved to '
# /opt/anaconda3/lib/python3.8/site-packages/pyUSID/io/dtype_utils.py:38: FutureWarning: pyUSID.io.dtype_utils.lazy_load_array has been moved to sidpy.hdf.hdf_utils.lazy_load_array. This copy in pyUSID willbe removed in future release. Please update your import statements
#   warn('pyUSID.io.dtype_utils.lazy_load_array has been moved to '
# /opt/anaconda3/lib/python3.8/site-packages/pyUSID/io/hdf_utils/base.py:133: UserWarning: pyUSID.io.hdf_utils.get_attributes has been moved to sidpy.hdf.hdf_utils.get_attributes. This copy in pyUSID willbe removed in future release. Please update your import statements
# ...

# %% [markdown]
# ## Plotting line between two selected points

# %%
# %matplotlib notebook
data.line_profile("Topography")
# Out:
# <img src="data:image/png;base64,..." width="300">
