# %%
# Import packages 

from vlabs.spm import *
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
import os

# %% [markdown]
# ## File preview function
#
# ### Select which h5 data file you want to look at, then you can select particular channel
#
# ### Topography, amplitude and phase are plotted
#
# ### Function will also print 'DART detected' and 'SF detected' depending on the type of data

# %%
data_dir = r"C:\Users\oliver\OneDrive - UNSW\Experiments\Experiments 2021\Asylum\210414"

file_preview(data_dir, cmap="afmhot")
# Out:
# interactive(children=(Dropdown(description='x', options=('C:\\Users\\oliver\\OneDrive - UNSW\\Experiments\\Exp…

# %%
scan = AsylumDART("Image0010.h5", data_dir = data_dir)
# Out:
# C:\Users\oliver\anaconda3\lib\site-packages\pyUSID\io\usi_data.py:151: UserWarning: This dataset does not have an N-dimensional form
#   warn('This dataset does not have an N-dimensional form')

# %%
scan.multi_image_plot(["Topography", "Amplitude_1", "Phase_1"])
# Out:
# <img src="data:image/png;base64,..." width="1200">
# (<Figure size 1200x400 with 6 Axes>,
#  [<AxesSubplot:xlabel='X ($\\mathrm{\\mu}$m)', ylabel='Y ($\\mathrm{\\mu}$m)'>,
#   <AxesSubplot:xlabel='X ($\\mathrm{\\mu}$m)'>,
#   <AxesSubplot:xlabel='X ($\\mathrm{\\mu}$m)'>])

# %%
scan.edge_detection("Phase_1", 2,-70,250)
# Out:
# Phase_1

# %%
phase = scan.phase_1

plt.imshow(phase[phase < 0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-726340942ead> in <module>
#       1 phase = scan.phase_1
#       2
# ----> 3 plt.imshow(phase[phase < 0])
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2907         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2908         url=url, **({"data": data} if data is not None else {}),
# -> 2909         **kwargs)
#    2910     sci(__ret)
#    2911     return __ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# ...

# %%
# %matplotlib notebook
fig, ax = plt.subplots()
#fig, ax = scan.single_image_plot("Phase_1", cmap="afmhot", units="degrees")
ax.imshow(np.flip(scan.channel_edges["Phase_1"], axis=0), interpolation="none")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = scan.single_image_plot("Phase_1", cmap="afmhot", units="degrees")
# Out:
# <img src="data:image/png;base64,..." width="300">
