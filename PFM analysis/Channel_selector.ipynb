# %%
from vlabs.spm import *
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %%
scan1 = AsylumData("data/P0125OP0004.h5")
# Out:
# C:\Users\oliver\anaconda3\lib\site-packages\pyUSID\io\usi_data.py:151: UserWarning: This dataset does not have an N-dimensional form
#   warn('This dataset does not have an N-dimensional form')

# %%
fig, ax = plt.subplots(figsize=(8,8))

scan1.single_image_plot("Topography", fig=fig, ax=ax)
# Out:
# (<Figure size 576x576 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x14ac249fe48>)

# %%
t = scan1.topography
a = scan1.amplitude_1
p = scan1.phase_1

def f(x):
    fig, ax = plt.subplots(figsize=(8,8))
    
    scan1.single_image_plot(x, fig=fig, ax=ax)
        
    return fig, ax


widgets.interact(f, x=["Topography", "Amplitude_1", "Phase_1", "Amplitude_2", "Phase_2"])
# Out:
# interactive(children=(Dropdown(description='x', options=('Topography', 'Amplitude_1', 'Phase_1', 'Amplitude_2'…
# <function __main__.f(x)>

# %%
widgets.interact?
