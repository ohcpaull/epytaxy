# %%
from vlabs.spm import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
scan1 = AsylumDART("data/P0125OP0004.h5")
# Out:
# C:\Users\oliver\anaconda3\lib\site-packages\pyUSID\io\usi_data.py:151: UserWarning: This dataset does not have an N-dimensional form
#   warn('This dataset does not have an N-dimensional form')

# %%
fig, ax = plt.subplots()
fig, ax = scan1.single_image_plot("Topography", ax=ax)
#fig, ax = plt.subplots()
import skimage.feature

#for idx, a in enumerate(ax):
    
edges = skimage.feature.canny(
        image=scan1.topography,
        sigma=5,
        low_threshold=-0.1e-9,
        high_threshold=0.1e-9,
    )

edges = np.invert(edges)
d = np.ma.masked_array(np.zeros((512,512)), edges)
ax.imshow(d, cmap="binary_r", interpolation="none")
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # Try with edge detection in .py file

# %%
from vlabs.spm import *
import matplotlib.pyplot as plt
import numpy as np
scan1 = AsylumDART("data/P0125OP0006.h5")
# Out:
# C:\Users\oliver\anaconda3\lib\site-packages\pyUSID\io\usi_data.py:151: UserWarning: This dataset does not have an N-dimensional form
#   warn('This dataset does not have an N-dimensional form')

# %%
scan1.edge_detection("Topography", 2,-.01e-9,.01e-9)
# Out:
# Topography

# %%
# %matplotlib notebook
fig, ax = scan1.single_image_plot("Topography", cmap="afmhot")
ax.imshow(scan1.channel_edges["Topography"], interpolation="none")
# Out:
# <img src="data:image/png;base64,..." width="553">

# %%
scan1.channel_edges
# Out:
# {}
